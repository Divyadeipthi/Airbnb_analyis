# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyadeipthi/Airbnb_analyis/blob/main/AIRBNB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymongo

# %%
pip install pandas

# %%
import numpy as np
import pandas as pd
import pymongo
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# change the API for your mongodb account
client = pymongo.MongoClient("mongodb+srv://Divya:deipthikaa142@cluster0.1pdmjhf.mongodb.net/?retryWrites=true&w=majority")
db = client.sample_airbnb
col = db.listingsAndReviews

rel_data = []
for i in col.find():
    data = dict(Id = i['_id'],
                Listing_url = i['listing_url'],
                Name = i.get('name'),
                Description = i['description'],
                House_rules = i.get('house_rules'),
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Min_nights = int(i['minimum_nights']),
                Max_nights = int(i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get('bedrooms'),
                Total_beds = i.get('beds'),
                Availability_365 = i['availability']['availability_365'],
                Price = i['price'],
                Security_deposit = i.get('security_deposit'),
                Cleaning_fee = i.get('cleaning_fee'),
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                No_of_reviews = i['number_of_reviews'],
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Amenities = ', '.join(i['amenities']),
                Host_id = i['host']['host_id'],
                Host_name = i['host']['host_name'],
                Street = i['address']['street'],
                Country = i['address']['country'],
                Country_code = i['address']['country_code'],
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_location_exact = i['address']['location']['is_location_exact']
    )
    rel_data.append(data)


df = pd.DataFrame(rel_data)
df
# Out:
#             Id                            Listing_url  \
# 0     10038496  https://www.airbnb.com/rooms/10038496
# 1     10006546  https://www.airbnb.com/rooms/10006546
# 2     10009999  https://www.airbnb.com/rooms/10009999
# 3      1001265   https://www.airbnb.com/rooms/1001265
# 4     10021707  https://www.airbnb.com/rooms/10021707
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9990304   https://www.airbnb.com/rooms/9990304
# 5552   9937100   https://www.airbnb.com/rooms/9937100
# 5553   9981541   https://www.airbnb.com/rooms/9981541
# 5554   9985696   https://www.airbnb.com/rooms/9985696
#
#                                                 Name  \
# 0                       Copacabana Apartment Posto 6
# 1                            Ribeira Charming Duplex
# 2                       Horto flat with small garden
# 3                   Ocean View Waikiki Marina w/prkg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 32 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   5555 non-null   object
#  1   Listing_url          5555 non-null   object
#  2   Name                 5555 non-null   object
#  3   Description          5555 non-null   object
#  4   House_rules          5555 non-null   object
#  5   Property_type        5555 non-null   object
#  6   Room_type            5555 non-null   object
#  7   Bed_type             5555 non-null   object
#  8   Min_nights           5555 non-null   int64
#  9   Max_nights           5555 non-null   int64
#  10  Cancellation_policy  5555 non-null   object
#  11  Accomodates          5555 non-null   int64
#  12  Total_bedrooms       5550 non-null   float64
#  13  Total_beds           5542 non-null   float64
#  14  Availability_365     5555 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Listing_url', 'Name', 'Description', 'House_rules',
#        'Property_type', 'Room_type', 'Bed_type', 'Min_nights', 'Max_nights',
#        'Cancellation_policy', 'Accomodates', 'Total_bedrooms', 'Total_beds',
#        'Availability_365', 'Price', 'Security_deposit', 'Cleaning_fee',
#        'Extra_people', 'Guests_included', 'No_of_reviews', 'Review_scores',
#        'Amenities', 'Host_id', 'Host_name', 'Street', 'Country',
#        'Country_code', 'Location_type', 'Longitude', 'Latitude',
#        'Is_location_exact'],
#       dtype='object')

# %%
df.shape
# Out:
# (5555, 32)

# %%
df.dtypes
# Out:
# Id                      object
# Listing_url             object
# Name                    object
# Description             object
# House_rules             object
# Property_type           object
# Room_type               object
# Bed_type                object
# Min_nights               int64
# Max_nights               int64
# Cancellation_policy     object
# Accomodates              int64
# Total_bedrooms         float64
# Total_beds             float64
# Availability_365         int64
# Price                   object
# Security_deposit        object
# Cleaning_fee            object
# Extra_people            object
# Guests_included         object
# No_of_reviews            int64
# Review_scores          float64
# Amenities               object
# Host_id                 object
# Host_name               object
# Street                  object
# Country                 object
# Country_code            object
# Location_type           object
# Longitude              float64
# ...

# %%
df.isna().sum()
# Out:
# Id                        0
# Listing_url               0
# Name                      0
# Description               0
# House_rules               0
# Property_type             0
# Room_type                 0
# Bed_type                  0
# Min_nights                0
# Max_nights                0
# Cancellation_policy       0
# Accomodates               0
# Total_bedrooms            5
# Total_beds               13
# Availability_365          0
# Price                     0
# Security_deposit       2084
# Cleaning_fee           1531
# Extra_people              0
# Guests_included           0
# No_of_reviews             0
# Review_scores          1474
# Amenities                 0
# Host_id                   0
# Host_name                 0
# Street                    0
# Country                   0
# Country_code              0
# Location_type             0
# Longitude                 0
# Latitude                  0
# Is_location_exact         0
# dtype: int64

# %%
df['Total_bedrooms'].value_counts()
# Out:
# 1.0     3308
# 2.0     1090
# 0.0      496
# 3.0      427
# 4.0      161
# 5.0       36
# 6.0       16
# 7.0        7
# 8.0        3
# 9.0        2
# 10.0       2
# 20.0       1
# 15.0       1
# Name: Total_bedrooms, dtype: int64

# %%
df.to_excel("airb.xlsx")

# %%
df.to_csv('airbnb.csv',index=False)

# %%
df=pd.read_csv("/content/airbnb.csv")
df
# Out:
#             Id                            Listing_url  \
# 0     10006546  https://www.airbnb.com/rooms/10006546
# 1     10009999  https://www.airbnb.com/rooms/10009999
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10030955  https://www.airbnb.com/rooms/10030955
# ...        ...                                    ...
# 5550   9983221   https://www.airbnb.com/rooms/9983221
# 5551   9985696   https://www.airbnb.com/rooms/9985696
# 5552   9987200   https://www.airbnb.com/rooms/9987200
# 5553   9990304   https://www.airbnb.com/rooms/9990304
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    Name  \
# 0                               Ribeira Charming Duplex
# 1                          Horto flat with small garden
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# ...
